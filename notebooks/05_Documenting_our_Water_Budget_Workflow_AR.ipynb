# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h1 style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">M3.5</span> – توثيق سير عمل ميزانية المياه</h1><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">جزء من: <a href="https://github.com/OpenClimateScience/M3-Open-Science-for-Water-Resources" dir="ltr">Open Science for Water Resources</a></p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">حسبنا ميزانية المياه لحوض <span dir="ltr" style="unicode-bidi: isolate;">Yellowstone</span>. لكن النتائج لا تصبح «قابلة لإعادة الإنتاج» إلا إذا وثّقنا: البيئة البرمجية، البيانات، والخطوات اللازمة لإعادة التشغيل. في هذا الدرس سنركز على توثيق سير العمل ومشاركته عبر <span dir="ltr" style="unicode-bidi: isolate;">Git</span> و<span dir="ltr" style="unicode-bidi: isolate;">GitHub</span>.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <hr/><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">نشر سير عمل علمي قابل لإعادة الإنتاج</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">نريد أن يتمكن أي شخص (بما في ذلك نحن مستقبلًا) من إعادة تشغيل التحليل من البداية والحصول على النتائج نفسها.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">رفع المستودع إلى GitHub</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">أنشئ مستودعًا على <span dir="ltr" style="unicode-bidi: isolate;">GitHub</span> ثم اربطه بمستودعك المحلي كمستودع بعيد (Remote).</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">من داخل مجلد المشروع نفّذ أوامر <span dir="ltr" style="unicode-bidi: isolate;">git remote add</span> ثم <span dir="ltr" style="unicode-bidi: isolate;">git push</span> لرفع الملفات والتاريخ إلى <span dir="ltr" style="unicode-bidi: isolate;">GitHub</span>.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">التحقق من حالة المستودعات البعيدة</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">استخدم <span dir="ltr" style="unicode-bidi: isolate;">git remote -v</span> للتأكد من عنوان المستودع البعيد، و<span dir="ltr" style="unicode-bidi: isolate;">git status</span> لمعرفة حالة ملفاتك.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">تحديث مستودع GitHub</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">بعد أي تغييرات جديدة: قم بـ <span dir="ltr" style="unicode-bidi: isolate;">git add</span> ثم <span dir="ltr" style="unicode-bidi: isolate;">git commit</span> ثم <span dir="ltr" style="unicode-bidi: isolate;">git push</span>.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <hr/>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ملف README</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">اكتب ملف <span dir="ltr" style="unicode-bidi: isolate;">README</span> يشرح: هدف المشروع، كيفية تثبيت الاعتمادات، كيفية تنزيل البيانات (أو الحصول عليها)، وكيفية تشغيل التحليل لإعادة إنتاج النتائج.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ملف الترخيص LICENSE</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">أضف ترخيصًا مفتوحًا مناسبًا (مثل <span dir="ltr" style="unicode-bidi: isolate;">MIT</span> أو <span dir="ltr" style="unicode-bidi: isolate;">Apache-2.0</span>) لتوضيح ما يمكن للآخرين فعله بالشيفرة.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <hr/><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">بعض الاقتراحات البرمجية</h2>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">الاستخدام المناسب لـ docstrings</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">اكتب <span dir="ltr" style="unicode-bidi: isolate;">docstrings</span> للدوال والوحدات لتوضيح: ما الذي تفعله، مُدخلاتها، مخرجاتها، ووحداتها.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">متغيّرات عالمية سهلة العثور</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ضع الثوابت/الإعدادات (مثل الفترة الزمنية أو المسارات) في أعلى الملف وبأسماء واضحة لتسهيل تعديلها.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">التعامل مع مسارات الملفات عبر الأنظمة</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">استخدم <span dir="ltr" style="unicode-bidi: isolate;">pathlib</span> للتعامل مع المسارات بطريقة تعمل على <span dir="ltr" style="unicode-bidi: isolate;">Windows</span> و<span dir="ltr" style="unicode-bidi: isolate;">Linux/Mac</span> دون تعديل يدوي.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <hr/>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">بهذه العناصر، يصبح مشروعك أقرب بكثير إلى «قابل لإعادة الإنتاج» ومفيدًا للآخرين وكذلك لنسختك المستقبلية.</p>
# </div>
